# %%
import pandas as pd
import numpy as np
import seaborn as sns                      
import matplotlib.pyplot as plt             
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("C:/Users/DELL/Desktop/New folder/PythonCourse/archive/data.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df = df.drop(['Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size'], axis=1)
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })

# %%
df.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %%
df.duplicated().sum()
# Out:
# 989

# %%
df.count()
# Out:
# Make            11914
# Model           11914
# Year            11914
# HP              11845
# Cylinders       11884
# Transmission    11914
# Drive Mode      11914
# MPG-H           11914
# MPG-C           11914
# Price           11914
# dtype: int64

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (10925, 10)

# %%
df.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Mode       0
# MPG-H            0
# MPG-C            0
# Price            0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Drive Mode      0
# MPG-H           0
# MPG-C           0
# Price           0
# dtype: int64

# %%
df.describe()
# Out:
#                Year            HP     Cylinders         MPG-H         MPG-C  \
# count  10827.000000  10827.000000  10827.000000  10827.000000  10827.000000
# mean    2010.896370    254.553062      5.691604     26.308119     19.327607
# std        7.029534    109.841537      1.768551      7.504652      6.643567
# min     1990.000000     55.000000      0.000000     12.000000      7.000000
# 25%     2007.000000    173.000000      4.000000     22.000000     16.000000
# 50%     2015.000000    240.000000      6.000000     25.000000     18.000000
# 75%     2016.000000    303.000000      6.000000     30.000000     22.000000
# max     2017.000000   1001.000000     16.000000    354.000000    137.000000
#
#               Price
# count  1.082700e+04
# mean   4.249325e+04
# std    6.229451e+04
# min    2.000000e+03
# 25%    2.197250e+04
# 50%    3.084500e+04
# 75%    4.330000e+04
# max    2.065902e+06

# %%
sns.boxplot(x=df["Price"])
plt.title("Price")
plt.show()

# %%
sns.boxplot(df["HP"])
plt.title("Horse Power")
plt.show()

# %%
df.Make.value_counts().nlargest(40).plot(kind="bar",figsize=(10,5))
plt.title("Number of cars by DERR")
plt.ylabel("Number of Cars ")
plt.xlabel("Make")
plt.show()

# %%
df.Year.value_counts().nlargest(15).plot(kind="bar",figsize=(10,5),legend=True)
plt.title("Yearly sales")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(["Transmission"])
plt.show()

# %%
group=df.groupby("Model")["Make"].count().sort_values(ascending=False).head(20)
group.plot(kind="bar",figsize=(12,6),width=0.3)
plt.title("Maximum Price For Each Model")
plt.xlabel("Model Name")
plt.ylabel("Price ")
plt.show()

# %%
group=df.groupby("Drive Mode")["Make"].count()
explode = (0.2, 0.2, 0.2, 0.2)
group.plot(kind="pie",figsize=(10,6),explode = explode,autopct='%1.1f%%')
plt.title(" Drive Mode and count of cars")
plt.ylabel("")
plt.show()
